# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

import re
import unidecode
from wordcloud import WordCloud, STOPWORDS

# %%
df = pd.read_csv('trabajos.csv',encoding='latin-1')
df.head()
# Out:
#                      Nombre_Empresa  Id_Empleo  \
# 0             Afilia RH Consultores     697589
# 1                          DIS-PLAS     697506
# 2  Universidad Privada Franz Tamayo     698406
# 3  Universidad Privada Franz Tamayo     698404
# 4  Universidad Privada Franz Tamayo     698405
#
#                              Ciudad  \
# 0  Santa Cruz de la Sierra, Bolivia
# 1  Santa Cruz de la Sierra, Bolivia
# 2  Santa Cruz de la Sierra, Bolivia
# 3                  El Alto, Bolivia
# 4                   La Paz, Bolivia
#
#                                       Categoria         Sueldo  \
# 0                          Logística y Almacén   No Declarado
# 1                           Marketing y Ventas   No Declarado
# 2  Atención al Cliente,Contabilidad y Economía   No Declarado
# 3  Atención al Cliente,Contabilidad y Economía   No Declarado
# 4  Atención al Cliente,Contabilidad y Economía   No Declarado
#
#            Publicado    Vencimiento  \
# 0  31 Diciembre 2018  30 Enero 2019
# 1  31 Diciembre 2018  30 Enero 2019
# 2  31 Diciembre 2018  30 Enero 2019
# 3  31 Diciembre 2018  30 Enero 2019
# 4  31 Diciembre 2018  30 Enero 2019
#
#                                          Descripcion  \
# 0  analista de logisticabase santa cruz objetivoe...
# 1  empresa de ventas de producto masivo requiere ...
# 2  estamos en la busqueda de un  asistente de pos...
# 3  estamos en la busqueda de un asistente de post...
# 4  estamos en la busqueda de un asistente de post...
#
#                           Nombre_cargo  \
# 0   Analista de Logística - Santa Cruz
# 1        Atención al Clientes y Ventas
# 2  Asistente de Postgrado - Santa Cruz
# 3     Asistente de Postgrado - El Alto
# 4      Asistente de Postgrado - La Paz
#
#                                               Enlace
# 0  https://www.trabajopolis.bo/oferta-de-trabajo-...
# 1  https://www.trabajopolis.bo/oferta-de-trabajo-...
# 2  https://www.trabajopolis.bo/oferta-de-trabajo-...
# 3  https://www.trabajopolis.bo/oferta-de-trabajo-...
# 4  https://www.trabajopolis.bo/oferta-de-trabajo-...

# %%
df.shape
# Out:
# (709, 10)

# %%
df.Id_Empleo.unique().shape
# Out:
# (709,)

# %%
df_new = df.drop_duplicates(subset ="Id_Empleo")

# %%
df_new.set_index('Id_Empleo', verify_integrity = True, inplace = True)

# %%
df_new['Publicado'].value_counts()
# Out:
# 10 Diciembre 2018    53
# 07 Diciembre 2018    52
# 28 Diciembre 2018    44
# 17 Diciembre 2018    40
# 11 Diciembre 2018    39
# 13 Diciembre 2018    37
# 14 Diciembre 2018    37
# 19 Diciembre 2018    35
# 18 Diciembre 2018    34
# 03 Diciembre 2018    34
# 12 Diciembre 2018    33
# 27 Diciembre 2018    33
# 05 Diciembre 2018    31
# 04 Diciembre 2018    27
# 21 Diciembre 2018    26
# 26 Diciembre 2018    25
# 31 Diciembre 2018    25
# 20 Diciembre 2018    24
# 15 Diciembre 2018    20
# 08 Diciembre 2018    18
# 24 Diciembre 2018    15
# 29 Diciembre 2018    13
# 22 Diciembre 2018    12
# 09 Diciembre 2018     1
# 06 Diciembre 2018     1
# Name: Publicado, dtype: int64

# %%
df_new['Sueldo'].value_counts()
# Out:
# No Declarado                      542
# De Bs. 2.060 a Bs. 2.999           48
# De Bs. 3.000 a Bs. 3.999           34
# Negociable                         29
# Dependiendo de la Experiencia      24
# De Bs. 4.000 a Bs. 4.999           13
# De Bs. 5.000 a Bs. 5.999           11
# De Bs. 10.000 a Bs. 14.999          3
# De Bs. 7.000 a Bs. 7.999            2
# De Bs. 8.000 a Bs. 8.999            2
# Mayores a Bs. 20.000                1
# Name: Sueldo, dtype: int64

# %%
df_new['Nombre_Empresa'].value_counts().head(10)
# Out:
# Importante Empresa                     24
# Banco Fassil - Trabaje con Nosotros    20
# Empresa Comercial                      18
# INDUSTRIAS FERROTODO LTDA.             15
# LUÁ S.R.L.                             11
# Importante Empresa Comercial           10
# Grupo Nacional Vida                    10
# Banco Pyme Ecofuturo S.A.              10
# Importante Empresa Industrial          10
# CARTONBOL                               9
# Name: Nombre_Empresa, dtype: int64

# %%
df_new['Ciudad'].value_counts()
# Out:
# Santa Cruz de la Sierra, Bolivia    453
# La Paz, Bolivia                     119
# Cochabamba, Bolivia                  74
# Oruro, Bolivia                       16
# El Alto, Bolivia                     15
# Sucre, Bolivia                        9
# Tarija, Bolivia                       8
# Potosí, Bolivia                       6
# Trinidad, Bolivia                     4
# Cobija, Bolivia                       3
# Otra Ciudad de Bolivia, Bolivia       2
# Name: Ciudad, dtype: int64

# %%
def column2text(feature):
    new_list = []
    # Separate by colon
    for element in feature:
        if ',' in element:
            tmp = element.split(',')
            new_list.append(tmp[0].rstrip())
            new_list.append(tmp[1].rstrip())
        else:
            new_categorias.append(element)
    # Merge all elements of list into a text        
    txt = ''
    for element in new_list:
        txt = txt + element + ' '
    # Clean text
    text = txt.lower().replace('\n','') #Get items without \n
    text = re.sub("(\(\w+\))", '', text) #Delete parenthesis
    #text = unidecode.unidecode(text) #Delete accents
    #text = re.sub('[^A-Za-z0-9\s]','',text) #Delete anything but letters, numbers and spaces
    clean_text = text.replace('  ', ' ')
    return clean_text

# %%
df_new['Nombre_cargo'].value_counts().head()
# Out:
# Ejecutivo(a) de Ventas                 10
# Ejecutivo(a) de Ventas - Santa Cruz    10
# Community Manager                       7
# Auxiliar Contable                       7
# Contador(a)                             4
# Name: Nombre_cargo, dtype: int64

# %%
temp = pd.DataFrame(new_categorias)
temp[0].value_counts().head()
# Out:
# Marketing y Ventas           577
# Administración y Oficina     392
# Contabilidad y Economía      172
# Banca y Finanzas             160
# Logística y Almacén          117
# Name: 0, dtype: int64

# %%
clean_text = column2text(categorias)

# %%
wordcloud = WordCloud(
    collocations=False,
    width = 2000,
    height = 1500,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(clean_text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
nombres_cargos = column2text(df_new['Nombre_cargo'])

# %%
#set the stopwords list
stopwords= set(STOPWORDS)

#append new words to the stopwords list
new_words = {'de', 'al', 'santa', 'cruz', 'cochabamba', 'la', 'paz'}
new_stopwords=stopwords.union(new_words)

wordcloud = WordCloud(
    collocations=False,
    width = 2000,
    height = 1500,
    background_color = 'black',
    stopwords = new_stopwords).generate(str(nombres_cargos))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ver qué dias publican más publicidad?
# en qué mes?
# de los informaticos, cuantos son en banca?
# eliminar stopwords espanol

# %% [markdown]
# If informatica:
#     descripcion =
#     wordCloud(descripcion)

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

import re
import unidecode
from wordcloud import WordCloud, STOPWORDS

# %%
df = pd.read_csv('trabajo123.csv',encoding='latin-1')
df.head()
# Out:
#                   Nombre_Empresa  Id_Empleo                            Ciudad  \
# 0  Importante Empresa Industrial     689938  Santa Cruz de la Sierra, Bolivia
# 1                  NOSSAMODA SRL     695472  Santa Cruz de la Sierra, Bolivia
# 2                   Univida S.A.     694359                   La Paz, Bolivia
# 3  Importante Empresa Industrial     689938  Santa Cruz de la Sierra, Bolivia
# 4                  NOSSAMODA SRL     695472  Santa Cruz de la Sierra, Bolivia
#
#                   Categoria                     Sueldo          Publicado  \
# 0  Contabilidad y Economía               No Declarado   21 Diciembre 2018
# 1  Contabilidad y Economía   De Bs. 3.000 a Bs. 3.999   19 Diciembre 2018
# 2  Contabilidad y Economía               No Declarado   15 Diciembre 2018
# 3  Contabilidad y Economía               No Declarado   21 Diciembre 2018
# 4  Contabilidad y Economía   De Bs. 3.000 a Bs. 3.999   19 Diciembre 2018
#
#      Vencimiento                                        Descripcion  \
# 0  20 Enero 2019  jefe de contabilidad y tesoreriaobjetivo del c...
# 1  18 Enero 2019  analista de tesoreria formacion titulado en au...
# 2  14 Enero 2019  analista de tesoreriasede la paz ref 2432018nd...
# 3  20 Enero 2019  jefe de contabilidad y tesoreriaobjetivo del c...
# 4  18 Enero 2019  analista de tesoreria formacion titulado en au...
#
#                        Nombre_cargo  \
# 0  Jefe de Contabilidad y Tesorería
# 1             Analista de Tesorería
# 2    Analista de Tesorería - La Paz
# 3  Jefe de Contabilidad y Tesorería
# 4             Analista de Tesorería
#
#                                               Enlace
# 0  https://www.trabajopolis.bo/oferta-de-trabajo-...
# 1  https://www.trabajopolis.bo/oferta-de-trabajo-...
# 2  https://www.trabajopolis.bo/oferta-de-trabajo-...
# 3  https://www.trabajopolis.bo/oferta-de-trabajo-...
# 4  https://www.trabajopolis.bo/oferta-de-trabajo-...

# %%
df.shape
# Out:
# (2394, 10)

# %%
df.Id_Empleo.unique().shape
# Out:
# (672,)

# %%
df_new = df.drop_duplicates(subset ="Id_Empleo")

# %%
df_new.shape
# Out:
# (672, 10)

# %%
df_new.set_index('Id_Empleo', verify_integrity = True, inplace = True)

# %%
df_new['Publicado'].value_counts()
# Out:
# 07 Diciembre 2018    51
# 10 Diciembre 2018    51
# 28 Diciembre 2018    43
# 17 Diciembre 2018    39
# 14 Diciembre 2018    36
# 11 Diciembre 2018    36
# 13 Diciembre 2018    34
# 19 Diciembre 2018    33
# 18 Diciembre 2018    32
# 03 Diciembre 2018    32
# 27 Diciembre 2018    30
# 12 Diciembre 2018    29
# 05 Diciembre 2018    29
# 04 Diciembre 2018    26
# 21 Diciembre 2018    25
# 31 Diciembre 2018    25
# 26 Diciembre 2018    25
# 20 Diciembre 2018    22
# 15 Diciembre 2018    18
# 08 Diciembre 2018    16
# 24 Diciembre 2018    15
# 29 Diciembre 2018    13
# 22 Diciembre 2018    10
# 06 Diciembre 2018     1
# 09 Diciembre 2018     1
# Name: Publicado, dtype: int64

# %%
df_new['Sueldo'].value_counts()
# Out:
# No Declarado                      516
# De Bs. 2.060 a Bs. 2.999           44
# De Bs. 3.000 a Bs. 3.999           32
# Negociable                         27
# Dependiendo de la Experiencia      23
# De Bs. 4.000 a Bs. 4.999           12
# De Bs. 5.000 a Bs. 5.999           10
# De Bs. 10.000 a Bs. 14.999          3
# De Bs. 7.000 a Bs. 7.999            2
# De Bs. 8.000 a Bs. 8.999            2
# Mayores a Bs. 20.000                1
# Name: Sueldo, dtype: int64

# %%
df_new['Nombre_Empresa'].value_counts().head(10)
# Out:
# Importante Empresa                     24
# Banco Fassil - Trabaje con Nosotros    19
# Empresa Comercial                      16
# INDUSTRIAS FERROTODO LTDA.             15
# LUÁ S.R.L.                             11
# Grupo Nacional Vida                    10
# Banco Pyme Ecofuturo S.A.              10
# Importante Empresa Comercial           10
# Importante Empresa Industrial           9
# CARTONBOL                               9
# Name: Nombre_Empresa, dtype: int64

# %%
df_new['Ciudad'].value_counts()
# Out:
# Santa Cruz de la Sierra, Bolivia    426
# La Paz, Bolivia                     114
# Cochabamba, Bolivia                  72
# Oruro, Bolivia                       15
# El Alto, Bolivia                     14
# Sucre, Bolivia                        9
# Tarija, Bolivia                       7
# Potosí, Bolivia                       6
# Trinidad, Bolivia                     4
# Cobija, Bolivia                       3
# Otra Ciudad de Bolivia, Bolivia       2
# Name: Ciudad, dtype: int64

# %%
def column2text(feature):
    new_list = []
    # Separate by colon
    for element in feature:
        if ',' in element:
            tmp = element.split(',')
            new_list.append(tmp[0].rstrip())
            new_list.append(tmp[1].rstrip())
        #else:
         #   new_categorias.append(element)
    # Merge all elements of list into a text        
    txt = ''
    for element in new_list:
        txt = txt + element + ' '
    # Clean text
    text = txt.lower().replace('\n','') #Get items without \n
    text = re.sub("(\(\w+\))", '', text) #Delete parenthesis
    #text = unidecode.unidecode(text) #Delete accents
    #text = re.sub('[^A-Za-z0-9\s]','',text) #Delete anything but letters, numbers and spaces
    clean_text = text.replace('  ', ' ')
    return clean_text

# %%
df_new['Nombre_cargo'].value_counts().head()
# Out:
# Ejecutivo(a) de Ventas - Santa Cruz    10
# Ejecutivo(a) de Ventas                 10
# Community Manager                       7
# Auxiliar Contable                       7
# Ejecutivos(as) de Ventas                4
# Name: Nombre_cargo, dtype: int64

# %%
clean_text = column2text(df_new['Categoria'])

# %%
wordcloud = WordCloud(
    collocations=False,
    width = 2000,
    height = 1500,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(clean_text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
nombres_cargos = column2text(df_new['Nombre_cargo'])

# %%
#set the stopwords list
stopwords= set(STOPWORDS)

#append new words to the stopwords list
new_words = {'de', 'al', 'santa', 'cruz', 'cochabamba', 'la', 'paz'}
new_stopwords=stopwords.union(new_words)

wordcloud = WordCloud(
    collocations=False,
    width = 2000,
    height = 1500,
    background_color = 'black',
    stopwords = new_stopwords).generate(str(nombres_cargos))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ver qué dias publican más publicidad?
# en qué mes?
# de los informaticos, cuantos son en banca?
# eliminar stopwords espanol

# %% [markdown]
# If informatica:
#     descripcion =
#     wordCloud(descripcion)
